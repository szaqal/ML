# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x = np.linspace(start=-5, stop=5, num=200)
fig, ax = plt.subplots()  
ax.plot(x, np.array([math.tanh(xi) for xi in x]) , label='tanh')
ax.plot(x, 1/(1+math.e**-x) , label='sigm')
ax.legend()

# %% [markdown]
# #### Differential

# %%
def f(x):
    return x**2

x = np.linspace(-10,10,500)
y = f(x)


fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(121)
ax.plot(x, y)

ax.set_title("y=f(x)")

delta_x = 0.001
y1 = (f(x+delta_x) - f(x))/delta_x
y2 = 2 * x

ax = fig.add_subplot(122)
ax.plot(x, y1, c="r", alpha=0.5, label="rate") #SAME
ax.plot(x, y2, c="b", alpha=0.5, label="rule") #SAME
ax.set_title("y=f'(x)")
ax.legend()
 
plt.show()

# %%
def f(x):
    return x**3 - 2*x**2+1 

x = np.linspace(-2,3,100)
y = f(x)


fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(121)
ax.plot(x, y)

ax.set_title("y=f(x)")

delta_x = 0.001
y1 = (f(x+delta_x) - f(x))/delta_x
y2 = 3*x**2 -4*x

ax = fig.add_subplot(122)
ax.plot(x, y1, c="r", alpha=0.5, label="rate") #SAME
ax.plot(x, y2, c="b", alpha=0.5, label="rule") #SAME
ax.set_title("y=f'(x)")
ax.legend()
 
plt.show()

# %% [markdown]
# ### Integration
#
# * [cumsum](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.cumsum.html)

# %%
def f(x):
    return 2*x

delta_x = 0.1
x = np.arange(-10, 10, delta_x)
fx = f(x) * delta_x
y = fx.cumsum()
plt.plot(x, y)
plt.show()

# %%
def f(x):
    return 3*x**2-4*x

delta_x = 0.1
x = np.arange(-2, 3, delta_x)
fx = f(x) * delta_x
y = fx.cumsum()
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(-10,10,1000)
xv, yv = np.meshgrid(x, x, indexing='ij')
 
zv = xv**2 + yv**3
 
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(xv, yv, zv, cmap="viridis")
plt.show()

# %%
x = np.linspace(-10,10,20)
xv, yv = np.meshgrid(x, x, indexing='ij')
 

fx = 2*xv
fy = 2*yv
 

size = np.sqrt(fx**2 + fy**2)
dir_x = fx/size
dir_y = fy/size
 

plt.figure(figsize=(6,6))
plt.quiver(xv, yv, dir_x, dir_y, size, cmap="viridis")
plt.show()

# %%
def f(x, y):
    return x**2 + y**3

angles = np.arange(0, 360, 0.1)    
x, y = 3, 4
step = 0.0001

maxdf, maxangle = -np.inf, 0
for angle in angles:
    # convert degree to radian
    rad = angle * np.pi / 180
    # delta x and delta y for a fixed step size
    dx, dy = np.sin(rad)*step, np.cos(rad)*step
    # rate of change at a small step
    df = (f(x+dx, y+dy) - f(x,y))/step
    # keep the maximum rate of change
    if df > maxdf:
        maxdf, maxangle = df, angle

dx, dy = np.sin(maxangle*np.pi/180), np.cos(maxangle*np.pi/180)
gradx, grady = dx*maxdf, dy*maxdf
print(f"Max rate of change at {maxangle} degrees")
print(f"Gradient vector at ({x},{y}) is ({dx*maxdf},{dy*maxdf})")
# Out:
# Max rate of change at 7.1000000000000005 degrees
# Gradient vector at (3,4) is (5.979187457261182,48.00378468698985)
